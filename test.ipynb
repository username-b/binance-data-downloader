# %%
import pandas as pd

# %%
df = pd.read_parquet(r'C:\projects\binance-data-downloader\ADAUSDT-1m-2024-03-28_2024-03-29.parquet')

# %%
df
# Out:
#         agg_trade_id   price  quantity  first_trade_id  last_trade_id  \
# 0          414762323  0.6485      11.0      1095510115     1095510115
# 1          414762324  0.6485     742.0      1095510116     1095510117
# 2          414762325  0.6486     154.0      1095510118     1095510118
# 3          414762326  0.6486       7.0      1095510119     1095510119
# 4          414762327  0.6485      11.0      1095510120     1095510120
# ...              ...     ...       ...             ...            ...
# 243473     415005796  0.6650     106.0      1096672781     1096672781
# 243474     415005797  0.6650      22.0      1096672782     1096672782
# 243475     415005798  0.6650   15899.0      1096672783     1096672793
# 243476     415005799  0.6649      44.0      1096672794     1096672794
# 243477     415005800  0.6650      30.0      1096672795     1096672795
#
#         transact_time  is_buyer_maker
# 0       1711584000018            True
# 1       1711584000172            True
# ...
